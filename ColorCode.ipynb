# %% [markdown]
# ## __Resistor Color Code Identifier__
#
# ///////////////////////////
# __Authour__ - WikumJCK
# //////////////////////////
# //////////////////////////
# __Date__   - 09/04/2022
# /////////////////////////
# ## __Documentation__
#
# * First, when an image is captured, we have to identify where the resistor is located in the image.
# * Then, According to that we have to crop the image.
# * After that, we have to find the orientation of the resistor.(We can use edge of the color lines for that)
# * Then according to that we have to change the orientation
# * Then Applying filters or another method we have to get the 4 main colors
# * After that we can decide the tolerence color and then calculate resistor value.
# * Then we can give the Output
#
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
# Importing all the Libraries
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 as cv

# %%
#Opening the image
img = cv.imread(r'./Images/330R.jpeg')
assert img is not None

plt.figure(figsize=(10,10),facecolor='white')
imgplot = plt.imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))
plt.show()
